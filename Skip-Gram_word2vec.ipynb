# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:24, 371KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random 

threshold_keep = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = { word: count/total_count for word, count in word_counts.items()}
p_drop = { word:1 -np.sqrt(threshold_keep/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx -R ) > 0 else 0
    stop = idx + R 
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6785 0.0999 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5944 0.0821 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4884 0.0797 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6087 0.0809 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5295 0.0779 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5612 0.0782 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5430 0.0774 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5153 0.0801 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4922 0.0795 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4271 0.0785 sec/batch
# Nearest to about: olof, calabria, blanco, cyr, indices, deformed, recherche, chubut,
# Nearest to eight: caliphate, rameau, umi, mintz, apollo, kilojoules, corbino, ionospheric,
# Nearest to years: caller, frescoes, activex, wellcome, pronounce, venture, bactria, silk,
# Nearest to one: solo, cottage, lc, rallying, heavily, rhein, volatility, stylish,
# Nearest to of: pillars, scientist, erected, sukhothai, landmass, url, tiwanaku, eidyn,
# Nearest to nine: serves, glas, film, danios, cytosol, four, breakwater, interactively,
# Nearest to only: harmonious, worthwhile, flawed, aleksey, tabla, breathing, whores, beginner,
# Nearest to for: loads, veishea, resistant, amen, interventionism, haloalkanes, renovated, moving,
# Nearest to award: recorders, reunified, vergina, lundy, blair, cedar, meetings, tithes,
# Nearest to operating: universitat, dante, estonian, undergo, maugham, alanis, florentines, bqp,
# Nearest to professional: scheldt, googolplex, anticommunist, rard, eudicots, unemployed, eelam, servicemen,
# Nearest to universe: blacksmiths, autonegotiation, absalon, hairless, linna, daddah, hoped, legionaries,
# Nearest to quite: borgia, dougal, personalities, sent, purported, watercolor, constellation, francaise,
# Nearest to joseph: integrative, flank, silty, grapes, petered, polskiej, realize, werner,
# Nearest to discovered: muratorian, dualism, asexual, versification, riefenstahl, cantors, standardisation, slovakia,
# Nearest to gold: vandalism, maxis, ausgleich, bova, urges, mathworld, treasure, transient,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4547 0.0803 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3537 0.0790 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3688 0.0825 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2473 0.0843 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1904 0.0867 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1861 0.0804 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1097 0.0846 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0689 0.0869 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0037 0.0832 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9884 0.0785 sec/batch
# Nearest to about: unlikely, issued, blanco, indices, impressive, chosen, olof, loading,
# Nearest to eight: caliphate, located, rameau, saint, baron, petrol, intimate, kilojoules,
# Nearest to years: caller, venture, wellcome, administration, bactria, frescoes, favour, admission,
# Nearest to one: solo, added, lc, hair, cottage, uv, rallying, midst,
# Nearest to of: pillars, man, scientist, output, concern, erected, question, sukhothai,
# Nearest to nine: serves, film, four, glas, two, cytosol, danios, dietary,
# Nearest to only: breathing, in, harmonious, beginner, enrolled, centralized, flawed, india,
# Nearest to for: moving, loads, bell, resistant, interventionism, horse, renovated, dmu,
# Nearest to award: recorders, meetings, lundy, blair, abbots, vergina, cedar, greatest,
# Nearest to operating: universitat, estonian, undergo, dante, southwestern, eats, interlisp, alanis,
# Nearest to professional: scheldt, rard, appears, googolplex, unemployed, doctrine, fix, anticommunist,
# Nearest to universe: blacksmiths, pearl, autonegotiation, hoped, shoot, decedent, linna, hairless,
# Nearest to quite: personalities, borgia, sent, dinosaurs, purported, dougal, turned, hollywood,
# Nearest to joseph: integrative, flank, socialism, realize, grapes, children, werner, silty,
# Nearest to discovered: muratorian, dualism, area, asexual, patients, riefenstahl, versification, harvested,
# Nearest to gold: vandalism, maxis, mathworld, urges, driven, treasure, bova, spotty,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9247 0.0792 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8983 0.0800 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8870 0.0811 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8424 0.0826 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7950 0.0812 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8293 0.0809 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7903 0.0832 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7820 0.0887 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8063 0.0858 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7730 0.0841 sec/batch
# Nearest to about: issued, blanco, indices, impressive, instituted, signature, calabria, loading,
# Nearest to eight: baron, migrant, rameau, jan, songwriter, caliphate, saint, located,
# Nearest to years: caller, frescoes, wellcome, venture, pronounce, administration, palace, purposely,
# Nearest to one: solo, rhein, rallying, midst, lc, added, embodying, vanzetti,
# Nearest to of: pillars, output, concern, man, question, degrade, scientist, sukhothai,
# Nearest to nine: four, film, serves, two, glas, cytosol, vol, american,
# Nearest to only: enrolled, breathing, whores, harmonious, arise, flawed, in, timelines,
# Nearest to for: resistant, loads, moving, horse, bell, overwhelmingly, interventionism, wronged,
# Nearest to award: meetings, blair, abbots, recorders, greatest, lundy, corresponds, sex,
# Nearest to operating: universitat, estonian, dante, undergo, maugham, southwestern, gliders, alanis,
# Nearest to professional: scheldt, googolplex, rard, unemployed, appears, fix, anticommunist, sweat,
# Nearest to universe: blacksmiths, pearl, shoot, hoped, antillean, decedent, daniel, autonegotiation,
# Nearest to quite: borgia, personalities, sent, turned, dougal, purported, dinosaurs, hollywood,
# Nearest to joseph: integrative, socialism, werner, flank, petered, frenchman, silty, advocates,
# Nearest to discovered: muratorian, dualism, area, riefenstahl, asexual, byzantium, versification, patients,
# Nearest to gold: vandalism, driven, treasure, maxis, mathworld, urges, transient, spotty,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7584 0.0837 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7555 0.0832 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7184 0.0831 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7217 0.0835 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7308 0.0846 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6852 0.0859 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6955 0.0848 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7347 0.0850 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6896 0.0843 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6642 0.0898 sec/batch
# Nearest to about: impressive, olof, signature, blanco, issued, calabria, instituted, cyr,
# Nearest to eight: songwriter, baron, jan, rameau, migrant, laureate, saint, leopold,
# Nearest to years: caller, frescoes, venture, islander, administration, pronounce, wellcome, bactria,
# Nearest to one: solo, three, seven, rhein, embodying, rallying, vanzetti, press,
# Nearest to of: pillars, sukhothai, degrade, concern, man, question, florentine, airframe,
# Nearest to nine: four, film, two, serves, american, breakwater, schawlow, vol,
# Nearest to only: breathing, enrolled, whores, harmonious, counselor, assure, flawed, tedious,
# Nearest to for: loads, resistant, horse, moving, wronged, renovated, interventionism, veishea,
# Nearest to award: meetings, abbots, blair, recorders, reunified, greatest, lundy, redemptive,
# Nearest to operating: universitat, estonian, dante, maugham, integer, alanis, undergo, gliders,
# Nearest to professional: scheldt, googolplex, rard, unemployed, parade, servicemen, fix, sweat,
# Nearest to universe: blacksmiths, shoot, pearl, antillean, decedent, hoped, ambassadorial, solstice,
# Nearest to quite: borgia, sent, personalities, turned, dougal, pentecostalism, dinosaurs, cocoa,
# Nearest to joseph: integrative, frenchman, werner, petered, socialism, quarreling, polskiej, children,
# Nearest to discovered: muratorian, dualism, riefenstahl, versification, asexual, byzantium, area, standardisation,
# Nearest to gold: vandalism, urges, maxis, treasure, mathworld, uncredited, heinous, driven,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6722 0.0862 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6708 0.0858 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6106 0.0859 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6063 0.0867 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6276 0.0863 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6391 0.0863 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5920 0.0647 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5471 0.0864 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5054 0.0867 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5109 0.0854 sec/batch
# Nearest to about: cyr, olof, impressive, blanco, signature, calabria, unlikely, airbags,
# Nearest to eight: laureate, jan, songwriter, baron, leopold, rameau, migrant, saint,
# Nearest to years: caller, frescoes, islander, administration, palace, wellcome, venture, office,
# Nearest to one: three, astronomer, solo, vanzetti, seven, historian, french, rhein,
# Nearest to of: pillars, degrade, sukhothai, pederasty, concern, arab, airframe, question,
# Nearest to nine: four, two, film, musician, american, painter, born, laureate,
# Nearest to only: breathing, whores, harmonious, counselor, enrolled, assure, tedious, sentry,
# Nearest to for: resistant, loads, moving, interventionism, horse, dmu, wronged, renovated,
# Nearest to award: blair, abbots, meetings, lundy, greatest, kiev, redemptive, campus,
# Nearest to operating: universitat, integer, maugham, estonian, alanis, input, dante, bqp,
# Nearest to professional: scheldt, rard, parade, fix, redistributed, googolplex, cracks, sweat,
# Nearest to universe: blacksmiths, shoot, definition, solstice, decedent, contradicted, hairless, tortosa,
# Nearest to quite: borgia, turned, personalities, xj, sent, cocoa, dougal, purported,
# Nearest to joseph: integrative, frenchman, petered, werner, socialism, robert, polskiej, quarreling,
# Nearest to discovered: muratorian, riefenstahl, dualism, byzantium, asexual, area, versification, holt,
# Nearest to gold: vandalism, treasure, maxis, heinous, uncredited, pinocchio, mathworld, urges,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5130 0.0858 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4730 0.0856 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4724 0.0862 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5401 0.0856 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4721 0.0884 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5058 0.0828 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4464 0.0890 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3777 0.0836 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4068 0.0829 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4419 0.0821 sec/batch
# Nearest to about: cyr, impressive, olof, blanco, urine, wages, chubut, recherche,
# Nearest to eight: jan, baron, laureate, rameau, leopold, migrant, cochran, dinky,
# Nearest to years: caller, islander, frescoes, female, palace, bactria, asphalt, office,
# Nearest to one: solo, three, fondation, rhein, embodying, lc, matthew, rallying,
# Nearest to of: pillars, concern, question, sukhothai, pederasty, degrade, least, arab,
# Nearest to nine: four, film, two, serves, stephan, hardcover, musician, breakwater,
# Nearest to only: whores, counselor, breathing, harmonious, worthwhile, fourths, tedious, sentry,
# Nearest to for: resistant, loads, moving, interventionism, wronged, horse, veishea, dmu,
# Nearest to award: blair, abbots, greatest, meetings, lundy, reunified, recorders, kennedy,
# Nearest to operating: universitat, integer, maugham, bqp, input, estonian, available, alanis,
# Nearest to professional: scheldt, fix, redistributed, googolplex, parade, sweat, servicemen, anointing,
# Nearest to universe: blacksmiths, definition, tortosa, hairless, shoot, dying, superposition, ambassadorial,
# Nearest to quite: borgia, xj, turned, pentecostalism, dougal, purported, sent, personalities,
# Nearest to joseph: integrative, frenchman, petered, werner, socialism, revel, quarreling, optimates,
# Nearest to discovered: muratorian, riefenstahl, dualism, byzantium, methodically, asexual, versification, holt,
# Nearest to gold: vandalism, treasure, conjecture, heinous, maxis, dinosauria, uncredited, participles,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4621 0.0831 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4089 0.0818 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4361 0.0814 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4049 0.0818 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4063 0.0817 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4515 0.0808 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3901 0.0809 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4309 0.0815 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4089 0.0814 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3592 0.0815 sec/batch
# Nearest to about: cyr, resolver, olof, wages, nagaoka, blanco, countercult, impressive,
# Nearest to eight: jan, laureate, rameau, leopold, baron, migrant, two, songwriter,
# Nearest to years: caller, islander, female, frescoes, asphalt, palace, complain, panned,
# Nearest to one: three, solo, fondation, astronomer, rhein, matthew, seven, embodying,
# Nearest to of: pillars, concern, question, names, sukhothai, oren, degrade, arab,
# Nearest to nine: four, film, two, stephan, hardcover, musician, zero, breakwater,
# Nearest to only: counselor, whores, harmonious, breathing, subtitles, fourths, in, worthwhile,
# Nearest to for: resistant, loads, rate, moving, wronged, veishea, dmu, interventionism,
# Nearest to award: blair, kennedy, abbots, greatest, meetings, telemachus, lundy, campus,
# Nearest to operating: universitat, maugham, bqp, integer, emulators, intermodal, interpreters, alanis,
# Nearest to professional: scheldt, sweat, super, defenseless, redistributed, googolplex, eudicots, servicemen,
# Nearest to universe: blacksmiths, shoot, tortosa, superposition, mathematicians, hairless, dying, symmetry,
# Nearest to quite: borgia, turned, xj, sent, dougal, possibly, pentecostalism, notice,
# Nearest to joseph: integrative, petered, werner, frenchman, revel, dru, socialism, robert,
# Nearest to discovered: muratorian, riefenstahl, dualism, versification, asexual, cantors, byzantium, trainees,
# Nearest to gold: vandalism, treasure, heinous, uncredited, conjecture, pinocchio, participles, driven,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3684 0.0810 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3866 0.0811 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3531 0.0813 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3880 0.0809 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3704 0.0802 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3648 0.0811 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3641 0.0814 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3653 0.0804 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3133 0.0801 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3464 0.0813 sec/batch
# Nearest to about: wages, cyr, olof, resolver, impressive, countercult, azrael, chubut,
# Nearest to eight: jan, two, migrant, rameau, baron, leopold, six, eugene,
# Nearest to years: female, caller, islander, frescoes, complain, palace, panned, asphalt,
# Nearest to one: three, seven, four, six, solo, astronomer, fondation, zero,
# Nearest to of: concern, pillars, arab, question, hoarding, situated, disasters, degrade,
# Nearest to nine: four, two, stephan, hydro, serves, hardcover, breakwater, zero,
# Nearest to only: subtitles, counselor, whores, harmonious, multiply, fourths, tedious, dealbata,
# Nearest to for: resistant, veishea, dmu, loads, moving, wronged, rate, purchase,
# Nearest to award: blair, kennedy, telemachus, abbots, mlb, greatest, recorders, nominated,
# Nearest to operating: universitat, maugham, networking, emulators, desktop, bqp, system, thz,
# Nearest to professional: scheldt, super, sweat, redistributed, servicemen, eudicots, defenseless, parade,
# Nearest to universe: blacksmiths, mathematicians, superposition, shoot, tortosa, solstice, sociologists, contradicted,
# Nearest to quite: borgia, turned, xj, sent, pentecostalism, dougal, possibly, cocoa,
# Nearest to joseph: integrative, petered, werner, frenchman, revel, dru, socialism, venerating,
# Nearest to discovered: muratorian, riefenstahl, dualism, versification, trainees, cantors, methodically, area,
# Nearest to gold: treasure, heinous, driven, uncredited, vandalism, participles, pinocchio, conjecture,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3307 0.0828 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2661 0.0806 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3673 0.0820 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3820 0.0803 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3551 0.0809 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3001 0.0812 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2895 0.0815 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3306 0.0807 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2346 0.0810 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2821 0.0811 sec/batch
# Nearest to about: cyr, olof, wages, blanco, impressive, resolver, countercult, chubut,
# Nearest to eight: two, jan, baron, six, migrant, laureate, rameau, leopold,
# Nearest to years: female, islander, fertility, caller, frescoes, bactria, mortality, palace,
# Nearest to one: three, seven, four, six, zero, astronomer, clemens, five,
# Nearest to of: degrade, concern, pillars, situated, hoarding, spiky, pederasty, balkan,
# Nearest to nine: four, two, zero, stephan, american, hydro, three, born,
# Nearest to only: subtitles, multiply, whores, harmonious, counselor, shades, tedious, sweetness,
# Nearest to for: veishea, resistant, rate, dmu, loads, moving, wronged, ayling,
# Nearest to award: kennedy, telemachus, blair, nominated, greatest, best, mlb, abbots,
# Nearest to operating: universitat, maugham, emulators, networking, desktop, mobile, bqp, system,
# Nearest to professional: scheldt, super, oates, eudicots, sweat, championship, defenseless, parade,
# Nearest to universe: blacksmiths, mathematicians, tortosa, sociologists, solstice, superposition, shoot, contradicted,
# Nearest to quite: turned, borgia, dougal, sent, possibly, pentecostalism, subpage, xj,
# Nearest to joseph: integrative, werner, petered, dru, revel, shamir, frenchman, agostino,
# Nearest to discovered: muratorian, riefenstahl, cantors, antiquity, byzantium, trainees, methodically, dualism,
# Nearest to gold: treasure, driven, participles, pinocchio, heinous, uncredited, maxis, nicephorus,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3165 0.0815 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2950 0.0808 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3420 0.0406 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2463 0.0813 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2162 0.0795 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2077 0.0803 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2331 0.0885 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2092 0.0828 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2155 0.0863 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1724 0.0899 sec/batch
# Nearest to about: cyr, olof, sinai, chubut, wages, blanco, impressive, gwynne,
# Nearest to eight: two, jan, baron, six, migrant, rameau, five, leopold,
# Nearest to years: female, islander, fertility, caller, frescoes, average, bactria, lawlessness,
# Nearest to one: three, four, six, seven, astronomer, clemens, zero, five,
# Nearest to of: situated, balkan, arab, concern, pederasty, degrade, spiky, islamic,
# Nearest to nine: four, two, hydro, stephan, zero, breakwater, hardcover, born,
# Nearest to only: subtitles, whores, shades, harmonious, sentry, counselor, dealbata, fourths,
# Nearest to for: veishea, resistant, dmu, moving, rate, loads, esa, system,
# Nearest to award: best, nominated, telemachus, kennedy, blair, mlb, tiles, recorders,
# Nearest to operating: universitat, maugham, emulators, intermodal, allowing, system, networking, thz,
# Nearest to professional: super, scheldt, sporting, championship, sweat, redistributed, postseason, fix,
# Nearest to universe: blacksmiths, tortosa, mathematicians, sociologists, solstice, daniel, hymn, superposition,
# Nearest to quite: turned, borgia, pentecostalism, subpage, dougal, possibly, cocoa, hearth,
# Nearest to joseph: integrative, werner, revel, petered, dru, socialism, venerating, circumcising,
# Nearest to discovered: muratorian, antiquity, riefenstahl, trainees, flees, methodically, phidias, argyle,
# Nearest to gold: treasure, driven, participles, heinous, pinocchio, uncredited, dinosauria, maxis,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2456 0.0919 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2334 0.0907 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2391 0.0895 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1147 0.0840 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1647 0.0835 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1588 0.0827 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1619 0.0865 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1994 0.0833 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2091 0.0831 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2046 0.0838 sec/batch
# Nearest to about: cyr, resolver, blanco, wages, impressive, sinai, olof, gifs,
# Nearest to eight: two, jan, six, migrant, five, rameau, mi, tchaikovsky,
# Nearest to years: female, fertility, islander, caller, average, frescoes, lawlessness, bactria,
# Nearest to one: three, four, six, seven, two, zero, five, fondation,
# Nearest to of: degrade, concern, situated, similarly, humble, pillars, buildings, proportionate,
# Nearest to nine: four, two, hydro, zero, stephan, three, breakwater, hardcover,
# Nearest to only: subtitles, harmonious, sentry, shades, whores, multiply, fourths, tedious,
# Nearest to for: resistant, veishea, dmu, moving, rate, deceit, folders, fsm,
# Nearest to award: nominated, best, telemachus, blair, strips, greatest, mlb, tiles,
# Nearest to operating: universitat, maugham, emulators, intermodal, multitasking, networking, somerset, thz,
# Nearest to professional: super, sporting, scheldt, sweat, redistributed, googolplex, fix, collegiate,
# Nearest to universe: blacksmiths, mathematicians, tortosa, shoot, solstice, daniel, contradicted, hairless,
# Nearest to quite: turned, borgia, dougal, subpage, pentecostalism, sent, totals, traveled,
# Nearest to joseph: integrative, werner, revel, petered, dru, socialism, circumcising, venerating,
# Nearest to discovered: muratorian, antiquity, riefenstahl, phidias, methodically, trainees, argyle, flees,
# Nearest to gold: driven, treasure, participles, heinous, uncredited, pinocchio, dinosauria, maxis,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1655 0.0829 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2231 0.0820 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1589 0.0828 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1348 0.0828 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1711 0.0822 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1843 0.0824 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2130 0.0838 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1488 0.0839 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1424 0.0829 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1785 0.0832 sec/batch
# Nearest to about: cyr, gifs, jel, gwynne, wages, sinai, impressive, medial,
# Nearest to eight: two, six, five, jan, migrant, one, rameau, four,
# Nearest to years: female, fertility, islander, average, caller, one, bactria, zero,
# Nearest to one: three, four, seven, six, two, zero, five, clemens,
# Nearest to of: concern, proportionate, situated, guericke, dia, pillars, spiky, similarly,
# Nearest to nine: four, two, zero, hydro, three, one, five, stephan,
# Nearest to only: subtitles, multiply, fourths, whores, shades, sentry, in, counselor,
# Nearest to for: veishea, resistant, deceit, moving, rate, dmu, folders, fsm,
# Nearest to award: best, nominated, telemachus, kennedy, blair, greatest, strips, mlb,
# Nearest to operating: universitat, emulators, maugham, multitasking, networking, qnx, ferroelectric, system,
# Nearest to professional: sporting, ronaldo, collegiate, scheldt, redistributed, sweat, super, googolplex,
# Nearest to universe: mathematicians, shoot, blacksmiths, daniel, solstice, tortosa, contradicted, superposition,
# Nearest to quite: turned, borgia, subpage, possibly, traveled, dougal, sent, brachiopods,
# Nearest to joseph: werner, integrative, dru, revel, socialism, petered, circumcising, venerating,
# Nearest to discovered: muratorian, antiquity, phidias, riefenstahl, argyle, trainees, chitin, aleph,
# Nearest to gold: driven, heinous, uncredited, participles, treasure, export, pinocchio, cucumbers,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2125 0.0829 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1642 0.0815 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1539 0.0823 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1837 0.0820 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1392 0.0853 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1282 0.0970 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1704 0.0912 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1162 0.0901 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2017 0.0843 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2125 0.0855 sec/batch
# Nearest to about: cyr, ambrosians, sinai, impressive, wages, olof, jel, gifs,
# Nearest to eight: two, six, five, one, nine, jan, seven, rameau,
# Nearest to years: female, fertility, bactria, lawlessness, one, islander, zero, caller,
# Nearest to one: three, four, seven, six, two, zero, five, nine,
# Nearest to of: concern, in, proportionate, humble, spiky, guericke, magnificence, dia,
# Nearest to nine: four, two, zero, three, one, five, eight, american,
# Nearest to only: subtitles, multiply, fourths, sentry, in, counselor, deviate, geq,
# Nearest to for: veishea, dmu, deceit, overwhelmingly, bol, reactionary, indulging, status,
# Nearest to award: best, nominated, telemachus, implicating, strips, greatest, awarded, milligan,
# Nearest to operating: universitat, maugham, emulators, multitasking, qnx, ferroelectric, somerset, thz,
# Nearest to professional: sporting, super, ronaldo, collegiate, scheldt, sweat, postseason, oates,
# Nearest to universe: mathematicians, shoot, blacksmiths, contradicted, tortosa, solstice, daniel, zoroaster,
# Nearest to quite: turned, borgia, subpage, dougal, europeans, sent, possibly, traveled,
# Nearest to joseph: werner, dru, integrative, revel, socialism, petered, bosco, rosicrucian,
# Nearest to discovered: muratorian, antiquity, phidias, riefenstahl, trainees, argyle, snes, chitin,
# Nearest to gold: treasure, uncredited, heinous, participles, driven, pinocchio, nicephorus, export,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2331 0.0833 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1345 0.0826 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1477 0.0835 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1584 0.0826 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0321 0.0828 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1344 0.0824 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1495 0.0833 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1161 0.0829 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1925 0.0210 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1213 0.0830 sec/batch
# Nearest to about: sinai, cyr, matos, jel, gifs, ambrosians, vetted, blanco,
# Nearest to eight: two, six, five, migrant, jan, seven, one, rameau,
# Nearest to years: female, fertility, lawlessness, bactria, july, over, caller, average,
# Nearest to one: three, four, seven, two, six, zero, five, nine,
# Nearest to of: in, concern, and, proportionate, guericke, spiky, the, luxembourgian,
# Nearest to nine: four, two, zero, three, one, hydro, five, american,
# Nearest to only: multiply, fourths, geq, subtitles, sentry, bouillon, sweetness, shades,
# Nearest to for: veishea, resistant, esa, dmu, bol, moving, fsm, a,
# Nearest to award: best, nominated, telemachus, implicating, winners, greatest, awards, blair,
# Nearest to operating: universitat, maugham, multitasking, qnx, emulators, ferroelectric, maglev, somerset,
# Nearest to professional: sporting, collegiate, ronaldo, super, sweat, ilr, redistributed, scheldt,
# Nearest to universe: tortosa, blacksmiths, shoot, mathematicians, daniel, solstice, contradicted, zoroaster,
# Nearest to quite: turned, europeans, subpage, borgia, possibly, traveled, cocoa, brachiopods,
# Nearest to joseph: werner, socialism, integrative, dru, revel, petered, yugoslavian, circumcising,
# Nearest to discovered: muratorian, antiquity, phidias, trainees, semiconductor, nazionale, argyle, cl,
# Nearest to gold: driven, heinous, treasure, participles, nicephorus, uncredited, export, pinocchio,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0668 0.0851 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0808 0.0827 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0852 0.0822 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0600 0.0831 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0858 0.0828 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0408 0.0816 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0835 0.0850 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0764 0.0845 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1182 0.0829 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0121 0.0834 sec/batch
# Nearest to about: matos, sinai, jel, gifs, gwynne, cyr, catamaran, consolations,
# Nearest to eight: two, six, five, migrant, seven, mi, jan, four,
# Nearest to years: female, fertility, average, over, july, bactria, lawlessness, zero,
# Nearest to one: three, four, seven, two, six, zero, five, nine,
# Nearest to of: in, guericke, spiky, and, situated, concern, luxembourgian, proportionate,
# Nearest to nine: four, two, zero, three, one, hydro, five, breakwater,
# Nearest to only: in, fourths, multiply, sentry, subtitles, sweetness, bouillon, whores,
# Nearest to for: veishea, esa, resistant, deceit, dmu, bol, moving, loads,
# Nearest to award: best, nominated, implicating, winners, telemachus, awarded, greatest, electroweak,
# Nearest to operating: universitat, maugham, multitasking, qnx, system, emulators, beos, thz,
# Nearest to professional: collegiate, sporting, ronaldo, super, sweat, postseason, scheldt, league,
# Nearest to universe: shoot, contradicted, mathematicians, daniel, blacksmiths, solstice, tortosa, magnified,
# Nearest to quite: turned, europeans, borgia, possibly, subpage, traveled, hearth, sent,
# Nearest to joseph: werner, integrative, socialism, dru, revel, circumcising, petered, marlow,
# Nearest to discovered: muratorian, antiquity, phidias, cosmic, nazionale, trainees, fpgas, flees,
# Nearest to gold: treasure, driven, nicephorus, heinous, uncredited, pinocchio, export, mined,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0445 0.0836 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0506 0.0821 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9998 0.0858 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0405 0.0838 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0909 0.0833 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0576 0.0831 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0341 0.0828 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1093 0.0832 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0332 0.0834 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0383 0.0835 sec/batch
# Nearest to about: jel, matos, gifs, cyr, consolations, sees, sinai, gwynne,
# Nearest to eight: two, six, five, seven, one, migrant, four, three,
# Nearest to years: female, fertility, average, over, zero, july, bactria, lawlessness,
# Nearest to one: three, four, seven, two, six, zero, five, nine,
# Nearest to of: in, and, spiky, concern, guericke, the, hydrologic, proportionate,
# Nearest to nine: four, two, zero, three, one, five, hydro, eight,
# Nearest to only: multiply, fourths, in, sweetness, subtitles, sentry, example, geq,
# Nearest to for: veishea, a, bah, esa, pennant, resistant, dmu, caer,
# Nearest to award: best, nominated, winners, awards, greatest, implicating, awarded, milligan,
# Nearest to operating: universitat, multitasking, maugham, qnx, emulators, beos, somerset, system,
# Nearest to professional: collegiate, sporting, ronaldo, super, carbondale, defenseless, ilr, postseason,
# Nearest to universe: mathematicians, daniel, shoot, contradicted, tortosa, magnified, blacksmiths, solstice,
# Nearest to quite: turned, borgia, europeans, subpage, totals, possibly, dougal, traveled,
# Nearest to joseph: werner, dru, integrative, socialism, revel, jocelyn, petered, marlow,
# Nearest to discovered: antiquity, muratorian, cosmic, phidias, kelvin, fpgas, nazionale, argyle,
# Nearest to gold: treasure, uncredited, nicephorus, pinocchio, driven, heinous, mined, participles,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0483 0.0844 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0716 0.0890 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0757 0.0845 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0397 0.0863 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0718 0.0922 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0915 0.0948 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0761 0.0832 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0614 0.0861 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0911 0.0859 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0617 0.0885 sec/batch
# Nearest to about: matos, jel, sinai, gifs, catamaran, obiang, consolations, apparition,
# Nearest to eight: two, six, five, seven, one, four, migrant, zero,
# Nearest to years: female, over, fertility, average, one, zero, july, lawlessness,
# Nearest to one: three, four, seven, two, six, zero, five, nine,
# Nearest to of: in, and, the, proportionate, spiky, situated, guericke, sukhothai,
# Nearest to nine: four, two, zero, three, one, five, eight, six,
# Nearest to only: in, multiply, subtitles, fourths, deviate, example, since, hugs,
# Nearest to for: veishea, esa, unknowns, deceit, bah, overwhelmingly, resistant, bol,
# Nearest to award: best, nominated, awards, awarded, winners, implicating, greatest, abbots,
# Nearest to operating: universitat, maugham, multitasking, somerset, qnx, emulators, system, ferroelectric,
# Nearest to professional: ronaldo, collegiate, sporting, super, carbondale, defenseless, sweat, ilr,
# Nearest to universe: mathematicians, shoot, daniel, contradicted, magnified, tortosa, cosmological, solstice,
# Nearest to quite: turned, borgia, subpage, europeans, totals, possibly, dougal, hearth,
# Nearest to joseph: werner, dru, socialism, integrative, revel, yugoslavian, marlow, wilberforce,
# Nearest to discovered: antiquity, muratorian, phidias, cosmic, kelvin, nazionale, fpgas, snes,
# Nearest to gold: nicephorus, export, mined, treasure, participles, heinous, driven, pinocchio,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0497 0.0920 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0342 0.0864 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0301 0.0859 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0603 0.0860 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0663 0.0917 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1144 0.0988 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1413 0.0910 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0409 0.0951 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0167 0.0956 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0819 0.0951 sec/batch
# Nearest to about: matos, gifs, sinai, obiang, wages, consolations, jel, catamaran,
# Nearest to eight: two, six, five, seven, one, zero, three, four,
# Nearest to years: female, over, fertility, average, july, zero, mortality, lawlessness,
# Nearest to one: three, four, seven, two, zero, six, five, nine,
# Nearest to of: in, and, the, spiky, guericke, luxembourgian, proportionate, humble,
# Nearest to nine: four, two, zero, three, one, five, eight, six,
# Nearest to only: in, multiply, example, geq, subtitles, familiar, bouillon, fourths,
# Nearest to for: esa, veishea, unknowns, bol, a, overwhelmingly, bah, philips,
# Nearest to award: best, nominated, winners, implicating, awards, awarded, greatest, electroweak,
# Nearest to operating: universitat, maugham, multitasking, system, qnx, emulators, somerset, umbrella,
# Nearest to professional: ronaldo, collegiate, sporting, super, players, carbondale, defenseless, sweat,
# Nearest to universe: mathematicians, shoot, daniel, contradicted, magnified, tortosa, cosmological, comics,
# Nearest to quite: turned, europeans, borgia, subpage, totals, possibly, dougal, bukovina,
# Nearest to joseph: werner, dru, socialism, revel, integrative, marlow, wilberforce, jocelyn,
# Nearest to discovered: antiquity, phidias, muratorian, cosmic, nazionale, kelvin, snes, westmoreland,
# Nearest to gold: nicephorus, treasure, mined, export, pinocchio, heinous, driven, reserves,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9600 0.0924 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0341 0.0908 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0228 0.0921 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0507 0.0908 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0985 0.0927 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0519 0.0951 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9934 0.0873 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9633 0.0872 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0174 0.0858 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9557 0.0827 sec/batch
# Nearest to about: matos, sinai, consolations, jel, ambrosians, gwynne, apparition, gifs,
# Nearest to eight: two, six, five, one, seven, four, three, zero,
# Nearest to years: female, over, fertility, average, july, mortality, zero, lawlessness,
# Nearest to one: three, four, seven, two, six, zero, five, nine,
# Nearest to of: in, and, the, spiky, guericke, situated, proportionate, earls,
# Nearest to nine: four, two, one, three, zero, five, eight, virologist,
# Nearest to only: in, multiply, since, bouillon, geq, almost, never, familiar,
# Nearest to for: esa, veishea, minute, overwhelmingly, dmu, unknowns, decompression, relieve,
# Nearest to award: best, nominated, winners, awards, awarded, implicating, abbots, electroweak,
# Nearest to operating: universitat, maugham, system, multitasking, somerset, qnx, ferroelectric, thz,
# Nearest to professional: collegiate, ronaldo, sporting, super, players, carbondale, league, west,
# Nearest to universe: shoot, mathematicians, tortosa, daniel, contradicted, comics, magnified, cosmological,
# Nearest to quite: turned, europeans, borgia, subpage, dougal, totals, possibly, hearth,
# Nearest to joseph: werner, socialism, dru, marlow, rosicrucian, wilberforce, jocelyn, revel,
# Nearest to discovered: antiquity, muratorian, phidias, cosmic, nazionale, westmoreland, engraver, vega,
# Nearest to gold: nicephorus, treasure, mined, pinocchio, heinous, export, file, driven,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9797 0.0883 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9417 0.0873 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9988 0.0867 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0349 0.0930 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0073 0.0909 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9638 0.0898 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9372 0.0870 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9542 0.0908 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9078 0.0877 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9401 0.0862 sec/batch
# Nearest to about: matos, sinai, consolations, gifs, jel, czapski, gwynne, hfs,
# Nearest to eight: two, six, five, one, seven, four, three, zero,
# Nearest to years: female, over, average, fertility, one, july, zero, households,
# Nearest to one: three, four, two, seven, six, zero, five, nine,
# Nearest to of: and, in, the, spiky, guericke, humble, similarly, proportionate,
# Nearest to nine: four, two, three, zero, one, five, six, eight,
# Nearest to only: in, multiply, almost, since, that, bindusara, bouillon, the,
# Nearest to for: esa, a, is, bol, minute, veishea, pennant, favors,
# Nearest to award: best, nominated, winners, awards, awarded, implicating, medal, greatest,
# Nearest to operating: universitat, maugham, multitasking, system, qnx, somerset, beos, interlisp,
# Nearest to professional: collegiate, ronaldo, sporting, carbondale, super, players, ilr, redistributed,
# Nearest to universe: mathematicians, cosmological, shoot, magnified, daniel, contradicted, comics, nordstr,
# Nearest to quite: turned, europeans, borgia, subpage, totals, dougal, hearth, cocoa,
# Nearest to joseph: werner, socialism, dru, rosicrucian, marlow, jocelyn, integrative, wilberforce,
# Nearest to discovered: antiquity, cosmic, phidias, muratorian, westmoreland, kelvin, vega, nazionale,
# Nearest to gold: nicephorus, mined, file, pinocchio, treasure, silver, reserves, export,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9932 0.1036 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0009 0.0857 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9931 0.0876 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0272 0.0867 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0170 0.0908 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9370 0.0884 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9697 0.0863 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9951 0.0899 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0098 0.0888 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0084 0.0949 sec/batch
# Nearest to about: matos, gwynne, consolations, jel, gifs, sinai, apparition, hfs,
# Nearest to eight: two, six, five, one, seven, three, four, zero,
# Nearest to years: female, average, over, july, zero, one, fertility, households,
# Nearest to one: three, four, seven, two, six, zero, five, nine,
# Nearest to of: in, and, the, guericke, spiky, an, luxembourgian, proportionate,
# Nearest to nine: four, two, three, one, zero, five, eight, six,
# Nearest to only: in, multiply, almost, subtitles, example, familiar, the, since,
# Nearest to for: esa, a, is, clk, bol, unknowns, favors, gains,
# Nearest to award: best, nominated, winners, awards, awarded, implicating, greatest, medal,
# Nearest to operating: universitat, maugham, system, multitasking, somerset, qnx, emulators, compatibility,
# Nearest to professional: collegiate, ronaldo, sporting, carbondale, west, super, sweat, ilr,
# Nearest to universe: cosmological, mathematicians, magnified, shoot, daniel, comics, contradicted, nordstr,
# Nearest to quite: turned, europeans, borgia, totals, subpage, oreille, cocoa, dougal,
# Nearest to joseph: werner, dru, marlow, socialism, wilberforce, jocelyn, rosicrucian, integrative,
# Nearest to discovered: antiquity, muratorian, cosmic, phidias, westmoreland, kelvin, vega, crystallographic,
# Nearest to gold: nicephorus, file, mined, pinocchio, treasure, silver, uncredited, driven,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9970 0.0960 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0025 0.0938 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9800 0.0840 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0167 0.0835 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0330 0.0883 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0032 0.0864 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9644 0.0833 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9558 0.0838 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9883 0.0825 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0153 0.0838 sec/batch
# Nearest to about: matos, consolations, wages, sinai, gwynne, gifs, hfs, jel,
# Nearest to eight: two, six, one, five, seven, four, three, zero,
# Nearest to years: female, over, average, july, fertility, year, zero, after,
# Nearest to one: three, four, seven, two, six, nine, five, zero,
# Nearest to of: in, and, the, spiky, guericke, proportionate, see, an,
# Nearest to nine: four, two, one, three, zero, five, eight, seven,
# Nearest to only: in, example, almost, exceptions, not, since, that, familiar,
# Nearest to for: esa, a, is, bol, which, in, unknowns, philips,
# Nearest to award: best, nominated, winners, awards, awarded, implicating, medal, greatest,
# Nearest to operating: universitat, system, multitasking, somerset, maugham, qnx, concept, shut,
# Nearest to professional: collegiate, ronaldo, sporting, carbondale, super, west, sweat, rolfe,
# Nearest to universe: cosmological, magnified, mathematicians, shoot, comics, daniel, contradicted, tortosa,
# Nearest to quite: turned, europeans, totals, borgia, subpage, hearth, oreille, sailor,
# Nearest to joseph: werner, dru, marlow, socialism, jocelyn, wilberforce, bosco, rosicrucian,
# Nearest to discovered: antiquity, phidias, muratorian, westmoreland, vega, cosmic, kelvin, nazionale,
# Nearest to gold: nicephorus, mined, silver, file, treasure, reserves, pinocchio, driven,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9783 0.0836 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0646 0.0825 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0714 0.0831 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0198 0.0826 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9561 0.0824 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9593 0.0887 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9527 0.0831 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9330 0.0826 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9791 0.0844 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9595 0.0820 sec/batch
# ...
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8385 0.0801 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7870 0.0794 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8176 0.0830 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8698 0.0809 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8289 0.0788 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8427 0.0792 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8560 0.0796 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8847 0.0793 sec/batch
# Nearest to about: at, matos, greenman, verifying, gwynne, luria, five, theban,
# Nearest to eight: one, two, six, seven, four, five, nine, three,
# Nearest to years: over, female, july, one, zero, year, two, jeppesen,
# Nearest to one: three, two, seven, four, six, five, nine, eight,
# Nearest to of: in, the, and, an, a, see, is, by,
# Nearest to nine: one, two, four, zero, three, eight, five, seven,
# Nearest to only: in, the, not, that, almost, a, and, sometimes,
# Nearest to for: and, the, a, in, is, of, as, or,
# Nearest to award: best, nominated, awards, winners, awarded, grammy, implicating, achievement,
# Nearest to operating: universitat, multitasking, unix, system, florentines, maugham, dos, shut,
# Nearest to professional: collegiate, ronaldo, super, wrestler, hydrographic, natufian, rolfe, alumnus,
# Nearest to universe: cosmological, daniel, inescapable, ditko, comics, revolved, refinements, signers,
# Nearest to quite: totals, turned, oreille, subpage, europeans, inventory, smokey, dinosaurs,
# Nearest to joseph: dru, werner, grundgesetz, marlow, rosicrucian, divide, wilberforce, saur,
# Nearest to discovered: phidias, antiquity, westmoreland, vega, actinide, fuzes, becquerel, fpgas,
# Nearest to gold: silver, mined, nicephorus, reserves, treasure, pinocchio, zinc, file,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8095 0.0809 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8307 0.0797 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8430 0.0795 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8681 0.0801 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8795 0.0794 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8730 0.0806 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8307 0.0789 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8189 0.0801 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8615 0.0802 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8982 0.0805 sec/batch
# Nearest to about: at, matos, luria, verifying, greenman, gwynne, five, hfs,
# Nearest to eight: two, one, six, seven, four, five, three, nine,
# Nearest to years: over, female, july, zero, one, year, two, six,
# Nearest to one: three, two, four, seven, five, six, nine, eight,
# Nearest to of: the, and, in, an, a, see, by, as,
# Nearest to nine: one, two, four, three, zero, eight, five, seven,
# Nearest to only: in, the, not, that, almost, is, a, since,
# Nearest to for: and, in, the, a, is, of, as, which,
# Nearest to award: best, awards, nominated, awarded, winners, hugo, grammy, implicating,
# Nearest to operating: universitat, florentines, maugham, system, unix, multitasking, shut, somerset,
# Nearest to professional: collegiate, ronaldo, super, hydrographic, wrestler, natufian, rolfe, alumnus,
# Nearest to universe: cosmological, daniel, comics, ditko, inescapable, revolved, signers, ducks,
# Nearest to quite: totals, turned, oreille, subpage, inventory, dinosaurs, europeans, clipperton,
# Nearest to joseph: dru, marlow, grundgesetz, werner, wilberforce, divide, rosicrucian, homemade,
# Nearest to discovered: antiquity, phidias, westmoreland, vega, fuzes, actinide, becquerel, testament,
# Nearest to gold: silver, mined, reserves, nicephorus, zinc, treasure, ore, bronze,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8820 0.0814 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8511 0.0799 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8400 0.0798 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8338 0.0793 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9299 0.0795 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8393 0.0795 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9890 0.0796 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9229 0.0792 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8931 0.0802 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8092 0.0797 sec/batch
# Nearest to about: at, matos, five, gwynne, verifying, luria, and, greenman,
# Nearest to eight: two, one, seven, six, four, five, three, nine,
# Nearest to years: female, over, july, zero, one, year, two, after,
# Nearest to one: two, three, four, seven, five, six, nine, eight,
# Nearest to of: the, and, in, see, an, a, for, by,
# Nearest to nine: one, two, four, zero, three, eight, five, seven,
# Nearest to only: in, the, not, that, almost, since, is, which,
# Nearest to for: and, a, the, in, of, is, as, which,
# Nearest to award: best, awards, nominated, awarded, winners, hugo, grammy, achievement,
# Nearest to operating: universitat, florentines, maugham, somerset, system, multitasking, unix, pra,
# Nearest to professional: collegiate, ronaldo, wrestler, super, hydrographic, natufian, rolfe, alumnus,
# Nearest to universe: cosmological, comics, daniel, ditko, inescapable, depicted, revolved, ducks,
# Nearest to quite: totals, turned, subpage, oreille, europeans, inventory, clipperton, dinosaurs,
# Nearest to joseph: marlow, dru, grundgesetz, wilberforce, werner, rosicrucian, divide, saur,
# Nearest to discovered: antiquity, westmoreland, phidias, fuzes, vega, intercal, becquerel, actinide,
# Nearest to gold: silver, mined, reserves, nicephorus, treasure, zinc, bronze, pinocchio,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8222 0.0804 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8241 0.0793 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7861 0.0798 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8794 0.0791 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8436 0.0806 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8765 0.0796 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8755 0.0587 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8669 0.0813 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8272 0.0786 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8733 0.0800 sec/batch
# Nearest to about: at, matos, greenman, gwynne, verifying, the, zero, luria,
# Nearest to eight: one, seven, two, six, four, five, nine, three,
# Nearest to years: july, over, female, zero, year, one, after, two,
# Nearest to one: four, seven, three, two, five, six, nine, eight,
# Nearest to of: the, in, and, an, a, by, see, on,
# Nearest to nine: one, two, four, eight, three, zero, five, seven,
# Nearest to only: in, the, not, that, since, with, a, is,
# Nearest to for: and, in, is, a, the, as, with, of,
# Nearest to award: best, nominated, awards, awarded, winners, hugo, grammy, implicating,
# Nearest to operating: universitat, system, florentines, maugham, unix, somerset, multitasking, shut,
# Nearest to professional: ronaldo, collegiate, super, wrestler, hydrographic, natufian, rolfe, professionally,
# Nearest to universe: cosmological, comics, ditko, daniel, inescapable, kablooie, villain, ducks,
# Nearest to quite: totals, turned, europeans, subpage, oreille, inventory, jovial, aspirations,
# Nearest to joseph: marlow, dru, wilberforce, rosicrucian, grundgesetz, werner, myth, saur,
# Nearest to discovered: antiquity, vega, phidias, fuzes, westmoreland, intercal, becquerel, testament,
# Nearest to gold: silver, mined, reserves, nicephorus, treasure, bronze, zinc, krugerrand,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7785 0.0797 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8235 0.0784 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7647 0.0795 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8706 0.0796 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8347 0.0804 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8738 0.0819 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8457 0.0792 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7432 0.0803 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7923 0.0788 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7890 0.0799 sec/batch
# Nearest to about: at, five, matos, zero, greenman, verifying, gwynne, luria,
# Nearest to eight: one, two, seven, six, four, five, three, nine,
# Nearest to years: female, over, july, zero, one, two, year, six,
# Nearest to one: two, three, four, seven, five, six, nine, eight,
# Nearest to of: the, in, and, see, a, an, is, as,
# Nearest to nine: one, two, four, zero, three, eight, five, seven,
# Nearest to only: the, in, not, that, a, with, since, is,
# Nearest to for: and, in, the, is, a, with, of, as,
# Nearest to award: best, nominated, awards, awarded, grammy, winners, hugo, achievement,
# Nearest to operating: universitat, florentines, system, unix, maugham, multitasking, somerset, localization,
# Nearest to professional: ronaldo, collegiate, super, hydrographic, wrestler, natufian, professionally, utr,
# Nearest to universe: cosmological, inescapable, comics, daniel, ditko, refinements, villain, revolved,
# Nearest to quite: totals, turned, oreille, inventory, europeans, jovial, conti, subpage,
# Nearest to joseph: marlow, dru, grundgesetz, rosicrucian, wilberforce, divide, homemade, saur,
# Nearest to discovered: vega, antiquity, becquerel, phidias, fuzes, actinide, westmoreland, intercal,
# Nearest to gold: silver, mined, treasure, reserves, nicephorus, bronze, zinc, copper,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7672 0.0805 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8470 0.0786 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8510 0.0811 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8098 0.0791 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8287 0.0800 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8904 0.0791 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8141 0.0786 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8251 0.0796 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8467 0.0795 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8620 0.0786 sec/batch
# Nearest to about: at, greenman, matos, gwynne, five, zero, verifying, interview,
# Nearest to eight: one, two, seven, six, four, five, three, nine,
# Nearest to years: female, over, july, zero, one, year, two, age,
# Nearest to one: three, two, seven, four, six, five, nine, eight,
# Nearest to of: the, in, and, an, a, is, see, as,
# Nearest to nine: one, two, four, zero, three, eight, seven, five,
# Nearest to only: in, the, not, with, that, a, last, is,
# Nearest to for: and, in, the, is, a, with, of, which,
# Nearest to award: best, nominated, awards, awarded, grammy, winners, hugo, achievement,
# Nearest to operating: universitat, florentines, unix, system, maugham, phil, somerset, excite,
# Nearest to professional: ronaldo, wrestler, collegiate, hydrographic, super, natufian, rolfe, alumnus,
# Nearest to universe: cosmological, daniel, inescapable, comics, ditko, revolved, villain, faq,
# Nearest to quite: totals, turned, oreille, inventory, europeans, jovial, clipperton, dinosaurs,
# Nearest to joseph: marlow, dru, grundgesetz, wilberforce, stead, rosicrucian, rigdon, saur,
# Nearest to discovered: vega, fuzes, actinide, becquerel, phidias, intercal, westmoreland, antiquity,
# Nearest to gold: silver, mined, nicephorus, treasure, reserves, bronze, pinocchio, zinc,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8362 0.0784 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8690 0.0780 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8415 0.0784 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8385 0.0790 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8752 0.0797 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8453 0.0789 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8516 0.0785 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7977 0.0787 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8123 0.0805 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7921 0.0803 sec/batch
# Nearest to about: at, five, zero, greenman, matos, gwynne, verifying, reported,
# Nearest to eight: one, two, seven, six, four, three, five, nine,
# Nearest to years: over, female, july, zero, one, year, two, six,
# Nearest to one: three, two, four, seven, five, six, nine, eight,
# Nearest to of: the, in, and, a, on, an, is, see,
# Nearest to nine: one, two, four, three, zero, seven, eight, five,
# Nearest to only: in, the, not, that, a, is, which, with,
# Nearest to for: in, the, a, and, is, with, which, of,
# Nearest to award: nominated, best, awards, awarded, grammy, hugo, winners, achievement,
# Nearest to operating: universitat, system, unix, florentines, multitasking, beos, maugham, dos,
# Nearest to professional: ronaldo, super, wrestler, collegiate, natufian, hydrographic, alumnus, rolfe,
# Nearest to universe: cosmological, comics, daniel, ditko, inescapable, revolved, ducks, veitch,
# Nearest to quite: totals, turned, europeans, inventory, jovial, oreille, aspirations, marshlands,
# Nearest to joseph: dru, marlow, grundgesetz, stead, wilberforce, rosicrucian, werner, divide,
# Nearest to discovered: becquerel, fuzes, vega, westmoreland, actinide, antiquity, intercal, phidias,
# Nearest to gold: silver, mined, treasure, nicephorus, reserves, bronze, zinc, medal,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8845 0.0810 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8400 0.0804 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9417 0.0791 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8923 0.0805 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8806 0.0789 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7964 0.0800 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7530 0.0790 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8554 0.0780 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7411 0.0790 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8823 0.0789 sec/batch
# Nearest to about: at, five, matos, greenman, zero, reported, gwynne, verifying,
# Nearest to eight: one, seven, two, six, four, nine, five, three,
# Nearest to years: female, over, july, zero, two, one, year, birth,
# Nearest to one: four, seven, three, nine, two, eight, five, six,
# Nearest to of: the, in, and, see, a, an, on, as,
# Nearest to nine: one, two, four, zero, eight, three, seven, five,
# Nearest to only: in, the, not, since, a, last, is, with,
# Nearest to for: in, and, the, a, with, is, as, of,
# Nearest to award: nominated, best, awards, awarded, grammy, hugo, winners, achievement,
# Nearest to operating: universitat, florentines, unix, phil, madox, maugham, shipyards, somerset,
# Nearest to professional: ronaldo, wrestler, super, natufian, hydrographic, rolfe, sweat, collegiate,
# Nearest to universe: cosmological, comics, ditko, daniel, villain, inescapable, revolved, veitch,
# Nearest to quite: totals, turned, jovial, europeans, oreille, inventory, subpage, marshlands,
# Nearest to joseph: marlow, dru, stead, myth, wilberforce, grundgesetz, homemade, rosicrucian,
# Nearest to discovered: fuzes, westmoreland, intercal, becquerel, vega, testament, interested, phidias,
# Nearest to gold: silver, mined, reserves, treasure, nicephorus, bronze, medal, krugerrand,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8280 0.0789 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8145 0.0798 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
